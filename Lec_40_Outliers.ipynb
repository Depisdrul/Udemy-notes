# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
# Let's see how we would find outliers in a dataset

# First we'll seed the numpy generator
np.random.seed(12345)

#Next we'll create the dataframe
dframe = DataFrame(np.random.randn(1000,4))

# %%
#Show preview
dframe.head()
# Out:
#           0         1         2         3
# 0 -0.204708  0.478943 -0.519439 -0.555730
# 1  1.965781  1.393406  0.092908  0.281746
# 2  0.769023  1.246435  1.007189 -1.296221
# 3  0.274992  0.228913  1.352917  0.886429
# 4 -2.001637 -0.371843  1.669025 -0.438570

# %%
# Lets describe the data
dframe.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067684     0.067924     0.025598    -0.002298
# std       0.998035     0.992106     1.006835     0.996794
# min      -3.428254    -3.548824    -3.184377    -3.745356
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.366626     2.653656     3.260383     3.927528

# %%
# Lets select the first column
col = dframe[0]

# %%
# NOw we can check which values in the column are greater than 3, for instance.
col[np.abs(col)>3]
# Out:
# 523   -3.428254
# 900    3.366626
# Name: 0, dtype: float64

# %%
# So we now know in column[0], rows 523 and 900 have values with abs > 3

#How about all the columns?

# We can use the "any" method
# dframe[(np.abs(dframe)>3).any(1)]
# BP this is wrong: any() takes 1 positional argument but 2 were given

# dframe[(np.abs(dframe)>3).any(axis=1)] # -> the pandas any takes the axis argument, but the python 2 does not
# anyways is it not clear what the axis=1 does

# This results in error
# dframe[(np.abs(dframe)>3).any(axis=0)]
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# Why does this not work? It returns all NaN
# dframe[np.abs(dframe)>3]
# Out:
#       0   1   2   3
# 0   NaN NaN NaN NaN
# 1   NaN NaN NaN NaN
# 2   NaN NaN NaN NaN
# 3   NaN NaN NaN NaN
# 4   NaN NaN NaN NaN
# ..   ..  ..  ..  ..
# 995 NaN NaN NaN NaN
# 996 NaN NaN NaN NaN
# 997 NaN NaN NaN NaN
# 998 NaN NaN NaN NaN
# 999 NaN NaN NaN NaN
#
# [1000 rows x 4 columns]

# %%
# WE could also possibly cap the data at 3

dframe[np.abs(dframe)>3] = np.sign(dframe) *3

# %%
dframe.describe()
# Out:
#                  0            1            2            3
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.067623     0.068473     0.025153    -0.002081
# std       0.995485     0.990253     1.003977     0.989736
# min      -3.000000    -3.000000    -3.000000    -3.000000
# 25%      -0.774890    -0.591841    -0.641675    -0.644144
# 50%      -0.116401     0.101143     0.002073    -0.013611
# 75%       0.616366     0.780282     0.680391     0.654328
# max       3.000000     2.653656     3.000000     3.000000

# %%
# Next we'll learn about Permutation!
