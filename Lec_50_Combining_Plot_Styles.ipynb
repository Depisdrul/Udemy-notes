# %%
# The normal imports
import numpy as np
from numpy.random import randn
import pandas as pd

# Import the stats library from numpy
from scipy import stats

# These are the plotting modules adn libraries we'll use:
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# Command so that plots appear in the iPython Notebook
# %matplotlib inline

# %%
# Now we'l learn how to combine plot styles

# %%
# Create datset
dataset = randn(100)

# Use distplot for combining plots, by default a kde over a histogram is shown
# sns.distplot(dataset,bins=25)  ### Deprecated
sns.displot(dataset,bins=25,kde=True)

# %%
# hist, rug, and kde are all input arguments to turn those plots on or off
# sns.distplot(dataset,rug=True,hist=False) ### Deprecated
sns.displot(dataset, kind='kde', rug=True)

# %%
# TO control specific plots in distplot, use [plot]_kws argument with dictionaries.

#Here's an example
### DEPRECATED
# sns.distplot(dataset,bins=25,
#              kde_kws={'color':'indianred','label':'KDE PLOT'},
#              hist_kws={'color':'blue','label':"HISTOGRAM"})

# THIS DOES NOT WORK
# sns.displot(dataset,bins=25, kind='hist', kde=True,
#              kde_kws={'color':'indianred','label':'KDE PLOT'},
#              hist_kws={'color':'blue','label':"HISTOGRAM"})
# sns.displot(dataset,bins=25, kind='hist', kde=True, color='indianred')

ax = sns.histplot(dataset, bins=25, kde=True, color='blue')
ax.lines[0].set_color('crimson')

# %%
# WE can also use pandas data objects for this

from pandas import Series

# Create Series form dataset
ser1 = Series(dataset,name='My_DATA')

# %%
# Plot Series
sns.displot(ser1,bins=25)

# %%
# Next up: We'll learn about box and violin plots!
